# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 9.4 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 32.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.0

# %%
# Baixando o data set em CSV
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/main/material%20de%20apoio/base%20de%20dados/Coordenadas%20csv.csv"

# %%
# Convertendo um CSV em um data frame pandas
estadios_df = pd.read_csv(dataset)

# %%
# Visualizando os 5 primeiros registros do DataFrame
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
# Convertendo em um dicionario
dicionario = estadios_df.to_dict('records')

# %%
# Visualizando o dicionario
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
# Estabelecendo umva variável que será o cliente de conexão ao server Mongo
cliente = MongoClient("mongodb+srv://williambraz65:123Elfos@clusterestadios.crevvpp.mongodb.net/?retryWrites=true&w=majority")

# %%
# Selecionando a base de dados
db = cliente.get_database('futebol')

# %%
# Insere os documentos na nova base de dados
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('655262f173773dc9b8f83f72'), ObjectId('655262f173773dc9b8f83f73'), ObjectId('655262f173773dc9b8f83f74'), ObjectId('655262f173773dc9b8f83f75'), ObjectId('655262f173773dc9b8f83f76'), ObjectId('655262f173773dc9b8f83f77'), ObjectId('655262f173773dc9b8f83f78'), ObjectId('655262f173773dc9b8f83f79'), ObjectId('655262f173773dc9b8f83f7a'), ObjectId('655262f173773dc9b8f83f7b'), ObjectId('655262f173773dc9b8f83f7c'), ObjectId('655262f173773dc9b8f83f7d'), ObjectId('655262f173773dc9b8f83f7e'), ObjectId('655262f173773dc9b8f83f7f'), ObjectId('655262f173773dc9b8f83f80'), ObjectId('655262f173773dc9b8f83f81'), ObjectId('655262f173773dc9b8f83f82'), ObjectId('655262f173773dc9b8f83f83'), ObjectId('655262f173773dc9b8f83f84'), ObjectId('655262f173773dc9b8f83f85')], acknowledged=True)

# %%
# Recuperando uma collection em uma variável
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['ac-3zmyigi-shard-00-00.crevvpp.mongodb.net:27017', 'ac-3zmyigi-shard-00-02.crevvpp.mongodb.net:27017', 'ac-3zmyigi-shard-00-01.crevvpp.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-j0j2n0-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('654e2dbf2049b053f251ad72'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('654e2e31368e506b1edd131d'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('654e2e31368e506b1edd131e'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('654e2e31368e506b1edd131f'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('654e2e31368e506b1edd1320'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('654e2e31368e506b1edd1321'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('654e2e31368e506b1edd1322'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654e2e31368e506b1edd1323'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('654e2e31368e506b1edd1324'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('654e2e31368e506b1edd1325'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('654e2e31368e506b1edd1326'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('654e2e31368e506b1edd1327'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('654e2e31368e506b1edd1328'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('654e2e31368e506b1edd1329'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654e2e31368e506b1edd132a'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('654e2e31368e506b1edd132b'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('654e2e31368e506b1edd132c'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('654e2e31368e506b1edd132d'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('654e2e31368e506b1edd132e'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('654e2e31368e506b1edd132f'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('654e2e31368e506b1edd1330'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265},
#  {'_id': ObjectId('655262f173773dc9b8f83f72'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('655262f173773dc9b8f83f73'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('655262f173773dc9b8f83f74'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('655262f173773dc9b8f83f75'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('655262f173773dc9b8f83f76'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('655262f173773dc9b8f83f77'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('655262f173773dc9b8f83f78'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('655262f173773dc9b8f83f79'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('655262f173773dc9b8f83f7a'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('655262f173773dc9b8f83f7b'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('655262f173773dc9b8f83f7c'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('655262f173773dc9b8f83f7d'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('655262f173773dc9b8f83f7e'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('655262f173773dc9b8f83f7f'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('655262f173773dc9b8f83f80'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('655262f173773dc9b8f83f81'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('655262f173773dc9b8f83f82'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('655262f173773dc9b8f83f83'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('655262f173773dc9b8f83f84'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('655262f173773dc9b8f83f85'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
# Estabelecendo um ponto central do mapa (Centro do Brasil)
center_lat = -14.24007
center_lon = -53.18050

# %%
# Todos os dados dos estadios na variavel consulta
consulta = list(estadios.find())

# %%
# Convertendo em um DataFrame
df_convertido = pd.DataFrame(consulta)

# %%
# Imprime a primeira linha do DataFrame
df_convertido.iloc[0]
# Out:
# _id           654e2dbf2049b053f251ad72
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
# Cria um mapa a partir do ponto central com 800x600
locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=5, width=800, heigth= 600)

# %%
# Recuperando a quantidade de pontos
qtde = len(df_convertido)

# %%
qtde
# Out:
# 41

# %%
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  descricao = 'Estádio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
  folium.Marker( [ lat , lng ],
                popup = descricao,
                icon = folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63e00e4bc4e700d5d7d066b77041fa4f {
#                     position: relative;
#                     width: 800.0px;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63e00e4bc4e700d5d7d066b77041fa4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63e00e4bc4e700d5d7d066b77041fa4f = L.map(
#                 &quot;map_63e00e4bc4e700d5d7d066b77041fa4f&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     heigth: 600,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc2ee587229208ded673036d5f10dc85 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_63e00e4bc4e700d5d7d066b77041fa4f);
#
#
#             var marker_47a771cacf4873745e47c9a5f274d5fc = L.marker(
#                 [-23.57243, -46.20123],
#                 {}
#             ).addTo(map_63e00e4bc4e700d5d7d066b77041fa4f);
#
#
#             var icon_236bd832a33779f3615a4fabfd29782e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_47a771cacf4873745e47c9a5f274d5fc.setIcon(icon_236bd832a33779f3615a4fabfd29782e);
#
#
#         var popup_014e8f5cf8c46bbf6e96bb2743a5a11d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_379ec211bf85da4b5c024ff18ad85e70 = $(`&lt;div id=&quot;html_379ec211bf85da4b5c024ff18ad85e70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Vila Belmiro&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_014e8f5cf8c46bbf6e96bb2743a5a11d.setContent(html_379ec211bf85da4b5c024ff18ad85e70);
#
#
#
#         marker_47a771cacf4873745e47c9a5f274d5fc.bindPopup(popup_014e8f5cf8c46bbf6e96bb2743a5a11d)
#         ;
#
#
#
#
#             var marker_21dfae1e85131f56c855a59e367ddae5 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_63e00e4bc4e700d5d7d066b77041fa4f);
#
#
#             var icon_d94d5ab11510a8c788ac6f36624c3cfc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_21dfae1e85131f56c855a59e367ddae5.setIcon(icon_d94d5ab11510a8c788ac6f36624c3cfc);
#
#
#         var popup_a779e5df6161eb67006b7660a49f10ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba5fba59e2e5fd8e0bcdbca0c692fdf6 = $(`&lt;div id=&quot;html_ba5fba59e2e5fd8e0bcdbca0c692fdf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_a779e5df6161eb67006b7660a49f10ab.setContent(html_ba5fba59e2e5fd8e0bcdbca0c692fdf6);
#
#
#
#         marker_21dfae1e85131f56c855a59e367ddae5.bindPopup(popup_a779e5df6161eb67006b7660a49f10ab)
#         ;
#
#
#
#
#             var marker_183b13212514ce5a8940c5a3e3315a93 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_63e00e4bc4e700d5d7d066b77041fa4f);
#
#
#             var icon_95818412125a4a5f5cd557dc8f31a2b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_183b13212514ce5a8940c5a3e3315a93.setIcon(icon_95818412125a4a5f5cd557dc8f31a2b3);
#
#
#         var popup_1b59bda8e9eb38ed14350e3f0630b8c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e29abae3331f7985631faf0591eb830 = $(`&lt;div id=&quot;html_7e29abae3331f7985631faf0591eb830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_1b59bda8e9eb38ed14350e3f0630b8c0.setContent(html_7e29abae3331f7985631faf0591eb830);
#
#
#
#         marker_183b13212514ce5a8940c5a3e3315a93.bindPopup(popup_1b59bda8e9eb38ed14350e3f0630b8c0)
#         ;
#
#
#
#
#             var marker_31692cd2c590ecd38cc20f832dc11eda = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_63e00e4bc4e700d5d7d066b77041fa4f);
#
#
#             var icon_d835399aa957a6e29
